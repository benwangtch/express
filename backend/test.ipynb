# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors

# %%
knn_selector = NearestNeighbors(n_neighbors=5)
data = pd.read_csv('./data/all_building.csv')

# %%
apartment_col = ['x座標', 'y座標', 'total_floor', 'house_age', '車位移轉總面積(坪)']
house_col = ['x座標', 'y座標', 'house_age', '土地移轉總面積(坪)', '建物移轉總面積(坪)','far']
building_col = ['x座標', 'y座標', '主建物面積', 'house_age']

# %%
selected_df = data.loc[:, building_col]

# %%
knn_selector.fit(selected_df)
# Out:
# /home/ben/anaconda3/envs/express/lib/python3.9/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /home/ben/anaconda3/envs/express/lib/python3.9/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /home/ben/anaconda3/envs/express/lib/python3.9/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# NearestNeighbors()

# %%
import pickle

# Save knn_selector object
with open('knn_building.pkl', 'wb') as f:
    pickle.dump(knn_selector, f)

# Load knn_selector object
with open('knn_building.pkl', 'rb') as f:
    knn_selector = pickle.load(f)

# %%
import pandas as pd
json_data = {
    'x座標': [1],
    'y座標': [2],
    'total_floor': [3],
    'house_age': [4],
    '車位移轉總面積(坪)': [5]
}

# Create DataFrame
X_input = pd.DataFrame(json_data, columns=['x座標', 'y座標', 'total_floor', 'house_age', '車位移轉總面積(坪)'])

# %%
_, indices = knn_selector_loaded.kneighbors(X_input)
# Out:
# /home/ben/anaconda3/envs/express/lib/python3.9/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /home/ben/anaconda3/envs/express/lib/python3.9/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /home/ben/anaconda3/envs/express/lib/python3.9/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
most_similar_data = data.iloc[indices[0]]

# %%
most_similar_data
# Out:
#         city_nm2  town_nm  交易車位  小坪數物件  建物型態  主要用途  主要建材  有無管理組織  車位類別  電梯  \
# 452984         5      145     0      1     2   588   111       1     2   0
# 452990         5      145     0      1     2   588   111       0     2   0
# 455076         5      145     0      0     0   588   111       0     2   0
# 480933         5      145     0      0     0   588   111       1     2   1
# 453416         5      145     0      1     2   588   111       0     2   0
#
#         ...  area_kilometer  population_density  house_price_index  \
# 452984  ...         4.91825               225.0             100.76
# 452990  ...         4.91825               225.0             100.76
# 455076  ...         4.91825               225.0             103.57
# 480933  ...         4.91825               225.0             110.61
# 453416  ...         4.91825               225.0              99.09
#
#         unemployment_rate  econ_rate  lending_rate  land_tx_count  land_price  \
# ...
