# %%
from dotenv import load_dotenv
import os

# %%
from dotenv import load_dotenv
import os

# Load .env file
# test = load_dotenv('../frontend/.env','REACT_APP_GOOGLE_MAPS_API_KEY')
test1 = os.getenv('REACT_APP_GOOGLE_MAPS_API_KEY')

# %%
print(test1)
# Out:
# AIzaSyBN-KUjRLmjjIrcVi1zkZKV9vwoWKK07dA
